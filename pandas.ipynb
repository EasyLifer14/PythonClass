# %%
#pandas
#csv

# %%
try:
    file = open('dates.csv', 'x')
    file = close()
except:
    pass

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 10.5/10.5 MB 8.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.6/14.6 MB 9.9 MB/s eta 0:00:00
# ...
#      ------------------------------------- 503.5/503.5 kB 10.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv('dates.csv')
df
# Out:
#    sn    name  age       add         phone
# 0   1   Rajan   24       ktm     984545454
# 1   2  Shreya   24    sangha     986654545
# 2   3     Ram   30  pulchowk    4555454545
# 3   4    Sita   22       ktm    6666644545
# 4   5   Shyam   33       bkt  787845454588
# 5   6   Sabin   30       ktm       4456458

# %%
df.head()
# Out:
#    sn    name  age       add         phone
# 0   1   Rajan   24       ktm     984545454
# 1   2  Shreya   24    sangha     986654545
# 2   3     Ram   30  pulchowk    4555454545
# 3   4    Sita   22       ktm    6666644545
# 4   5   Shyam   33       bkt  787845454588

# %%
df.head(3)
# Out:
#    sn    name  age       add       phone
# 0   1   Rajan   24       ktm   984545454
# 1   2  Shreya   24    sangha   986654545
# 2   3     Ram   30  pulchowk  4555454545

# %%
df.tail()
# Out:
#    sn    name  age       add         phone
# 1   2  Shreya   24    sangha     986654545
# 2   3     Ram   30  pulchowk    4555454545
# 3   4    Sita   22       ktm    6666644545
# 4   5   Shyam   33       bkt  787845454588
# 5   6   Sabin   30       ktm       4456458

# %%
import pandas as pd
df = pd.read_csv('dates.csv',index_col = 'sn')
df
# Out:
#       name  age       add         phone
# sn
# 1    Rajan   24       ktm     984545454
# 2   Shreya   24    sangha     986654545
# 3      Ram   30  pulchowk    4555454545
# 4     Sita   22       ktm    6666644545
# 5    Shyam   33       bkt  787845454588
# 6    Sabin   30       ktm       4456458

# %%
import pandas as pd
cols = ['name','sn','phone']
df = pd.read_csv('dates.csv',index_col = 'sn',usecols = cols)
df
# Out:
#       name         phone
# sn
# 1    Rajan     984545454
# 2   Shreya     986654545
# 3      Ram    4555454545
# 4     Sita    6666644545
# 5    Shyam  787845454588
# 6    Sabin       4456458

# %%
import pandas as pd
col = ['name','sn','phone']
df = pd.read_csv('dates.csv',index_col = 'sn',usecols = col)
df
# Out:
#       name         phone
# sn
# 1    Rajan     984545454
# 2   Shreya     986654545
# 3      Ram    4555454545
# 4     Sita    6666644545
# 5    Shyam  787845454588
# 6    Sabin       4456458

# %%
import pandas as pd
df = pd.read_csv('dates.csv',index_col = 'sn')
df.iloc[1:4]
# Out:
#       name  age       add       phone
# sn
# 2   Shreya   24    sangha   986654545
# 3      Ram   30  pulchowk  4555454545
# 4     Sita   22       ktm  6666644545
